# %% [markdown]
# well we handled 3 topics Multiqubit states, Operators and Eigenvalue today

# %% [markdown]
# ## Bulding a Quantum Computer book exercises

# %% [markdown]
# # 2.7 Exersises

# %% [markdown]
# 2.1 Orthogonality of bell states:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.2 Entangled states: Prove that the state α |00> + β |11> can not be written as the tensor product of two states and is thus entangled. α and β are both nonzero.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 2.3 Mixed states: Consider a system which has a probability of $\frac13$ of being in the ${\mathrm{state}}$ $|\psi\rangle$ a probability of $\frac{2}{3}$ of being in the state $|\phi\rangle$ where,
# $$
# \begin{aligned}&|\psi\rangle=\frac{2}{\sqrt{5}}\left|+\right\rangle+\frac{1}{\sqrt{5}}\left|-\right\rangle\\&|\phi\rangle=\frac{1}{\sqrt{5}}\left|+i\right\rangle-\frac{2}{\sqrt{5}}\left|-i\right\rangle\end{aligned}
# $$
#
# $(|\pm i\rangle$ are the eigenstates of $\hat{\sigma}_y)$. Write the density matrix representing this state.

# %% [markdown]
# 2.4 Purity: We saw that the density matrix of a state, ρˆ, can be written in terms of a so-called
# Bloch vector ~n as,
# a. Show that the eigenvalues of ρˆ are 1
# 2
# (1 ± |~n|).
# b. The purity of a state is sometimes defined as P = tr...
# Why is it called the purity?
#
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
#
#
# OR
#
#
# https://quantumcomputing.stackexchange.com/questions/5993/what-is-the-meaning-of-writing-a-state-in-its-bloch-representation
#
# https://physics.stackexchange.com/questions/292102/how-do-one-show-that-the-pauli-matrices-together-with-the-unit-matrix-form-a-bas
#
# https://edu.itp.phys.ethz.ch/hs14/QIT/Solutions2.pdf
#
# http://theory.caltech.edu/~preskill/ph219/chap2_15.pdf [check Bloch sphere part]

# %% [markdown]
# 2.6. Mixed subsystems: The state in Eq. (2.54) illustrated an interesting property of entan￾glement: we can have full knowledge of the combined state of a system (i.e. it’s in a pure
# state), but have no knowledge (i.e. it is a totally mixed state) of the state of one of its
# subsystems. When a bipartite system’s state is maximally entangled we have no knowledge
# of either subsystem. Prove that the Bell states are the only maximally entangled two-qubit
# states
#
# ![image.png](attachment:image.png)
#
# https://quantumcomputing.stackexchange.com/questions/2263/how-do-i-show-that-a-two-qubit-state-is-an-entangled-state

# %%
import numpy as np
from numpy.linalg import matrix_power

r_1 = 0.1
r_2 = 0.2
r_3 = 0.3

A = np.array([[1+r_1, r_1-1j*r_2], [r_1+1j*r_2, 1-r_3]])
matrix_power(A, 2)
print(matrix_power(A, 2))
# Out:
# [[1.26+0.j   0.18-0.36j]
#  [0.18+0.36j 0.54+0.j  ]]
